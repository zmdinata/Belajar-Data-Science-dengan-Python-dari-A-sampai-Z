# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.DataFrame([["C1", 10, "Bandung", "Jan"],
                   ["C2", 15, "Jakarta", "Feb"],
                   ["C3", 20, "Bogor", "March"],
                   ["C4", 35, "Tangerang", "Apr"]],
                  columns = ["cust_id", "item_bought", "city", "join_month"])
df
# Out:
#   cust_id  item_bought       city join_month
# 0      C1           10    Bandung        Jan
# 1      C2           15    Jakarta        Feb
# 2      C3           20      Bogor      March
# 3      C4           35  Tangerang        Apr

# %%
df.to_csv("customers_info.csv", index=False)

# %%
df.to_excel("customers_info.xlsx", index=False)

# %%
#Load a DataFrame csv
df = pd.read_csv("customers_info.csv")

# %%
df
# Out:
#   cust_id  item_bought       city join_month
# 0      C1           10    Bandung        Jan
# 1      C2           15    Jakarta        Feb
# 2      C3           20      Bogor      March
# 3      C4           35  Tangerang        Apr

# %%
#Load a DataFrame excel
df = pd.read_excel("customers_info.xlsx")
df
# Out:
#   cust_id  item_bought       city join_month
# 0      C1           10    Bandung        Jan
# 1      C2           15    Jakarta        Feb
# 2      C3           20      Bogor      March
# 3      C4           35  Tangerang        Apr

# %% [markdown]
# ***Basic Operation***

# %%
df = pd.DataFrame({
    'cust_id': ['c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'c7', 'c8', 'c9', 'c10'],
    'item_bought': [10,15,20,35,5,8,10,2,9,18],
    'city': ["Jakarta", "Bogor", "Bogor", "Tangerang", "Bali", "Jakarta", "Jakarta", "Bandung", "Bogor", "Jakarta"]
})

df
# Out:
#   cust_id  item_bought       city
# 0      c1           10    Jakarta
# 1      c2           15      Bogor
# 2      c3           20      Bogor
# 3      c4           35  Tangerang
# 4      c5            5       Bali
# 5      c6            8    Jakarta
# 6      c7           10    Jakarta
# 7      c8            2    Bandung
# 8      c9            9      Bogor
# 9     c10           18    Jakarta

# %%
#Summary info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   cust_id      10 non-null     object
#  1   item_bought  10 non-null     int64
#  2   city         10 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 372.0+ bytes

# %%
#statistics of numerical columns
df.describe()
# Out:
#        item_bought
# count    10.000000
# mean     13.200000
# std       9.461031
# min       2.000000
# 25%       8.250000
# 50%      10.000000
# 75%      17.250000
# max      35.000000

# %%
#columns name
df.columns
# Out:
# Index(['cust_id', 'item_bought', 'city'], dtype='object')

# %%
list(df.columns)
# Out:
# ['cust_id', 'item_bought', 'city']

# %%
for i in list(df.columns):  #iteration(looping)
    print(i + "2")
# Out:
# cust_id2
# item_bought2
# city2

# %%
#DataFrame Length
df.shape
# Out:
# (10, 3)

# %%
df.shape[0] #banyaknya baris
# Out:
# 10

# %%
df.shape[1] #banyaknya columns
# Out:
# 3

# %%
#Values of a Particular columns
df["cust_id"]
# Out:
# 0     c1
# 1     c2
# 2     c3
# 3     c4
# 4     c5
# 5     c6
# 6     c7
# 7     c8
# 8     c9
# 9    c10
# Name: cust_id, dtype: object

# %%
df["item_bought"]
# Out:
# 0    10
# 1    15
# 2    20
# 3    35
# 4     5
# 5     8
# 6    10
# 7     2
# 8     9
# 9    18
# Name: item_bought, dtype: int64

# %%
df["city"]
# Out:
# 0      Jakarta
# 1        Bogor
# 2        Bogor
# 3    Tangerang
# 4         Bali
# 5      Jakarta
# 6      Jakarta
# 7      Bandung
# 8        Bogor
# 9      Jakarta
# Name: city, dtype: object

# %%
#Values of Several Columns
df[["city","item_bought"]]
# Out:
#         city  item_bought
# 0    Jakarta           10
# 1      Bogor           15
# 2      Bogor           20
# 3  Tangerang           35
# 4       Bali            5
# 5    Jakarta            8
# 6    Jakarta           10
# 7    Bandung            2
# 8      Bogor            9
# 9    Jakarta           18

# %%
df[["cust_id","city","item_bought"]]
# Out:
#   cust_id       city  item_bought
# 0      c1    Jakarta           10
# 1      c2      Bogor           15
# 2      c3      Bogor           20
# 3      c4  Tangerang           35
# 4      c5       Bali            5
# 5      c6    Jakarta            8
# 6      c7    Jakarta           10
# 7      c8    Bandung            2
# 8      c9      Bogor            9
# 9     c10    Jakarta           18

# %%
#First N rows of df
df.head() #kalo gada angka nanti cuma nampilin 5 doang defaultnya
# Out:
#   cust_id  item_bought       city
# 0      c1           10    Jakarta
# 1      c2           15      Bogor
# 2      c3           20      Bogor
# 3      c4           35  Tangerang
# 4      c5            5       Bali

# %%
df.head(1)
# Out:
#   cust_id  item_bought     city
# 0      c1           10  Jakarta

# %%
df.head(10)
# Out:
#   cust_id  item_bought       city
# 0      c1           10    Jakarta
# 1      c2           15      Bogor
# 2      c3           20      Bogor
# 3      c4           35  Tangerang
# 4      c5            5       Bali
# 5      c6            8    Jakarta
# 6      c7           10    Jakarta
# 7      c8            2    Bandung
# 8      c9            9      Bogor
# 9     c10           18    Jakarta

# %%
#Last N rows of df
df.tail() #sama kek df.head() dan lainnya
# Out:
#   cust_id  item_bought     city
# 5      c6            8  Jakarta
# 6      c7           10  Jakarta
# 7      c8            2  Bandung
# 8      c9            9    Bogor
# 9     c10           18  Jakarta

# %%
#Random N rows of df
df.sample() #hanya mengambil 1 baris random doang
# Out:
#   cust_id  item_bought   city
# 1      c2           15  Bogor

# %%
df.sample(3)
# Out:
#   cust_id  item_bought     city
# 9     c10           18  Jakarta
# 6      c7           10  Jakarta
# 8      c9            9    Bogor

# %%
#sorting data
df.sort_values(by = "item_bought", ascending=False) #descending
# Out:
#   cust_id  item_bought       city
# 3      c4           35  Tangerang
# 2      c3           20      Bogor
# 9     c10           18    Jakarta
# 1      c2           15      Bogor
# 0      c1           10    Jakarta
# 6      c7           10    Jakarta
# 8      c9            9      Bogor
# 5      c6            8    Jakarta
# 4      c5            5       Bali
# 7      c8            2    Bandung

# %%
df.sort_values(by = "item_bought") #ascending
# Out:
#   cust_id  item_bought       city
# 7      c8            2    Bandung
# 4      c5            5       Bali
# 5      c6            8    Jakarta
# 8      c9            9      Bogor
# 6      c7           10    Jakarta
# 0      c1           10    Jakarta
# 1      c2           15      Bogor
# 9     c10           18    Jakarta
# 2      c3           20      Bogor
# 3      c4           35  Tangerang

# %%
df.sort_values(by = ["item_bought", "cust_id"]) #kalo several coloumns harus ada list di dalam by
# Out:
#   cust_id  item_bought       city
# 7      c8            2    Bandung
# 4      c5            5       Bali
# 5      c6            8    Jakarta
# 8      c9            9      Bogor
# 0      c1           10    Jakarta
# 6      c7           10    Jakarta
# 1      c2           15      Bogor
# 9     c10           18    Jakarta
# 2      c3           20      Bogor
# 3      c4           35  Tangerang

# %%
df.sort_values(by = ["item_bought", "cust_id"]).reset_index() #mengurutkan nomer index setelah sorting
# Out:
#    index cust_id  item_bought       city
# 0      7      c8            2    Bandung
# 1      4      c5            5       Bali
# 2      5      c6            8    Jakarta
# 3      8      c9            9      Bogor
# 4      0      c1           10    Jakarta
# 5      6      c7           10    Jakarta
# 6      1      c2           15      Bogor
# 7      9     c10           18    Jakarta
# 8      2      c3           20      Bogor
# 9      3      c4           35  Tangerang

# %%
#Rename Columns
df.rename(columns = {"cust_id": "customer_id", "item_bought": "num_of_items"}) #ngubah beberapa nama kolom
# Out:
#   cust_id2  item_bought2      city2
# 0       c1            10    Jakarta
# 1       c2            15      Bogor
# 2       c3            20      Bogor
# 3       c4            35  Tangerang
# 4       c5             5       Bali
# 5       c6             8    Jakarta
# 6       c7            10    Jakarta
# 7       c8             2    Bandung
# 8       c9             9      Bogor
# 9      c10            18    Jakarta

# %%
df.columns = ["cust_id2", "item_bought2", "city2"] #kalo mau ngubah semua nama kolom
df
# Out:
#   cust_id2  item_bought2      city2
# 0       c1            10    Jakarta
# 1       c2            15      Bogor
# 2       c3            20      Bogor
# 3       c4            35  Tangerang
# 4       c5             5       Bali
# 5       c6             8    Jakarta
# 6       c7            10    Jakarta
# 7       c8             2    Bandung
# 8       c9             9      Bogor
# 9      c10            18    Jakarta

# %%
#Change/Converting data types
df
# Out:
#   cust_id2  item_bought2      city2
# 0       c1            10    Jakarta
# 1       c2            15      Bogor
# 2       c3            20      Bogor
# 3       c4            35  Tangerang
# 4       c5             5       Bali
# 5       c6             8    Jakarta
# 6       c7            10    Jakarta
# 7       c8             2    Bandung
# 8       c9             9      Bogor
# 9      c10            18    Jakarta

# %%
df["item_bought2"] = df["item_bought2"].astype("int64")

# %%
df.info() #before rewrite type df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_id2      10 non-null     object
#  1   item_bought2  10 non-null     int64
#  2   city2         10 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 372.0+ bytes

# %%
df["item_bought2"] = df["item_bought2"].astype("float64") #sekalian rewrite type dataframenya

# %%
df.info() #after rewrite type DF
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_id2      10 non-null     object
#  1   item_bought2  10 non-null     float64
#  2   city2         10 non-null     object
# dtypes: float64(1), object(2)
# memory usage: 372.0+ bytes

# %%
df["item_bought2"] = df["item_bought2"].astype("object")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_id2      10 non-null     object
#  1   item_bought2  10 non-null     object
#  2   city2         10 non-null     object
# dtypes: object(3)
# memory usage: 372.0+ bytes
